# %% [markdown]
# # Exercise 3. Explore The Entire Dataset (Advanced)
# > Note: This exercise is optional and is meant for those of you who want to freestyle a bit more.
#
# I want you to take the approaches that I showed you in exercises 1 and 2, and expand them to fit an exploration of the entire dataset! While you are welcome to free-style, I encourage you to keep a focus on the words still! I'll introduce you to other NLP methods in the coming weeks :))

# %% [markdown]
# If you followed the UCloud setup, you should have mounted the `resources` folder! This contains an additional `data/` folder where `herbold_2023_essays.csv` is present in its entirety. You should be able to load the data with pandas as such:

# %%
import pandas as pd
from pathlib import Path

# define general path (pathlib is my fave way to load stuff - if you haven't seen it before, I suggest you try to use it for a while!!)
path = Path.cwd()  
print(path)

# load data
data_path = path.parents[2] / "resources" / "data" / "herbold_2023_essays.csv"
df = pd.read_csv(data_path, sep=";")
# Out:
# /Users/au675000/Desktop/teaching/book.nosync/nlp-at-cogsci/book/class1

# %%
df
# Out:
#     id         File                                              Topic  \
# 0    0  essay01.txt  Should students be taught to compete or to coo...
# 1    1  essay02.txt  More people are migrating to other countries t...
# 2    2  essay03.txt  International tourism is now more common than ...
# 3    3  essay04.txt  International tourism is now more common than ...
# 4    4  essay05.txt                       Living and studying overseas
# ..  ..          ...                                                ...
# 85  85  essay86.txt  teaching and researching working together lead...
# 86  86  essay87.txt  Can petrol price increase impact on reducing t...
# 87  87  essay88.txt  Prefer to live in a small town rather than a city
# 88  88  essay89.txt  Knowledge from experience is more important th...
# 89  89  essay90.txt  Solve traffic and housing problems by moving c...
#
#                                               Student  \
# 0   It is always said that competition can effecti...
# ...

# %% [markdown]
# Surprise! There is also essays from `ChatGPT-3` that you can explore in addition to `ChatGPT-4`

# %% [markdown]
# ## Your Turn: Exploring the Dataset

# %% [markdown]
# :::{admonition} HANDS-ON
# :class: red
#
# This page contains no set exercises nor any solutions from me. It is meant for you to explore the RQ more in depth and perhaps even make up your own RQs. I do encourage you to stick with exploring the dataset on a word-basis like we have done previously, just on a larger scale.
#
#  I do however, have some suggestions on what you could do.
#
# - Get a feel for the dataset. What is the scope of the dataset? An example could be to explore the kinds of essay topics you are dealing with.
# - Instead of looking at one essay at a time, consider ways to extract results from all essays and ways to aggregate them (you can use `pandas`)
# - Be creative with the plotting - are there other ways that would be more fun to plot than a bar plot`
# - Did you know that spaCy can also extract Named Entities? Perhaps it would be fun to explore that!
# :::
