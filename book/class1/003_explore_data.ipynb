# %% [markdown]
# # Exercise 3. Explore The Entire Dataset
# Let's turn to exploring the entire dataset, using and expanding upon approaches from exercises 1 and 2!
#
# :::{important}
# This exercise is relatively open and intended for more free-styling (with suggestions below). **If you are feeling uninspired *or* just want to switch it up**, you could consider starting with [Exercise 4](4-BPE-intro)
#
# If you have the time, I recommend going back to this exercise at home though!
# ::::

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# If you followed the [Class Setup](class-setup), you should have mounted the `resources` folder!
#
# This contains an additional `data/` folder where `herbold_2023_essays.csv` is located. You should be able to load the data with `pandas` as such:

# %%
import pandas as pd
from pathlib import Path

# define general path (pathlib is my fave way to load stuff - if you haven't seen it before, I suggest you try to use it for a while!!)
path = Path.cwd()  

# load data
data_path = path.parents[1] / "resources" / "data" / "herbold_2023_essays.csv"
df = pd.read_csv(data_path, sep=";")

# %%
df.head(5)
# Out:
#    id         File                                              Topic  \
# 0   0  essay01.txt  Should students be taught to compete or to coo...
# 1   1  essay02.txt  More people are migrating to other countries t...
# 2   2  essay03.txt  International tourism is now more common than ...
# 3   3  essay04.txt  International tourism is now more common than ...
# 4   4  essay05.txt                       Living and studying overseas
#
#                                              Student  \
# 0  It is always said that competition can effecti...
# 1  The last 50 years have seen an increasing numb...
# 2  The last decade has seen an increasing number ...
# 3  The last 50 years have seen a significant incr...
# 4  It is every student's desire to study at a goo...
#
#                                            ChatGPT-3  \
# 0  Education is not only about acquiring knowledg...
# 1  Migration has been a part of human history for...
# 2  International tourism has become an increasing...
# ...

# %% [markdown]
# Surprise! There is also essays from `ChatGPT-3` that you can explore in addition to `ChatGPT-4` :)

# %% [markdown]
# ## Your Turn: Exploring the Dataset

# %% [markdown]
# :::{admonition} HANDS-ON
# :class: red
#
# This page contains no set exercises nor any solutions from me. It is meant for you to explore the RQ more in depth and perhaps even make up your own RQs. I do encourage you to stick with exploring the dataset on a word-basis like we have done previously, just on a larger scale.
#
#  I have some suggestions:
#
# - Get a feel for the dataset: What is the scope of the dataset? An example could be to explore the kinds of essay topics you are dealing with.
# - Instead of looking at one essay at a time, consider ways to extract results from all essays and ways to aggregate them (you can use `pandas`).
# - Be creative with the plotting: Are there other ways that would be more fun to plot than a bar plot (See also [Python Graph Gallery](https://python-graph-gallery.com/)).
# - Did you know that spaCy can also extract [Named Entities](https://spacy.io/usage/spacy-101#annotations-ner)? Perhaps it would be fun to explore that!
# :::
