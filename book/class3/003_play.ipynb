# %% [markdown]
# ## Exercise 3. Play with Embeddings!
# There are many great things to do with embeddings ! Mostly in code, but also as games :)

# %% [markdown]
# ## 3.1 Guess the Secret Word of The Day
# Finally an exercise for gamers!! I want you to briefly jump out of UCloud and your code to go explore embeddings in a web app:
# :::{admonition} HANDS-ON
# :class: red
# Hop onto [semantle.com](https://semantle.com/) and try to guess the word of the day!
# :::

# %% [markdown]
# ## 3.2 Classification with Embeddings
# Instead of using BOW or TF-IDF representations of text data, we can also use embeddings for classification!
#
# :::{admonition} HANDS-ON
# :class: red
# 1. Read through [this notebook](https://github.com/CHCAA-EDUX/NLP-AU/blob/main/nbs/class_2b.ipynb) from last year's course to understand how to represent your text as `glove` embeddings!
#
# 2. Use the dataset and your classification workflow from last class to classify `human` versus `cohere`
# :::
