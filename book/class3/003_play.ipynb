# %% [markdown]
# ## Exercise 3. Play with Embeddings!
# There are many great things to do with embeddings ! Mostly in code, but also as games :)

# %% [markdown]
# ## 3.1 Guess the Word of The Day
# Finally an exercise for gamers!! Jump out of UCloud and go explore embeddings in a game:
# :::{admonition} HANDS-ON
# :class: red
# You will try to guess the word of the day on the website below. As you play, reflect on your process. Does your new knowledge about embeddings help you?
#
# <p style="text-align: center;">
#   <a href="https://semantle.com/" target="_blank">Play SEMANTLE</a>
# </p>
#
# :::

# %% [markdown]
# ## 3.2 Classification with Embeddings
# We can also use embeddings to represent our text for classification! This can both be done with static word embeddings, but also sentence / document embeddings.
#
# :::{admonition} HANDS-ON
# :class: red
# **TASK A: Classify word embeddings**
# - Download [this notebook](https://github.com/MinaAlmasi/nlp-at-cogsci/blob/main/materials/classify_word_embeddings.ipynb) from last year's course.
# - Run through the notebook to classify `sentiment` from `words` using `glove` embeddings.
#
# **TASK B: Classify document embeddings**
# Use `SentenceTransformers` instead of BOW/TF-IDF in the workflow from {ref}`Class 2 <class2-exercise2>`. This involves:
# - Embedding the `generation` column from `human` versus `cohere` using a `SentenceTransformer` model.
# - Running the same classification/evaluation pipeline as in {ref}`Class 2 <class2-exercise2>`.
#     - (If `LogisticRegression` fails to converge, try adjusting parameters such as `C = ...`.)
#
# For help with **TASK B**, see this [Kaggle notebook](https://www.kaggle.com/code/abdulrahmanatef/classification-using-sentence-transformer).
#
# :::
